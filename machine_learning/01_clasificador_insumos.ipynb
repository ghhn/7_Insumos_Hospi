# %% [markdown]
# # Laboratorio de IA: Clasificador de Insumos
# En este cuaderno experimentaremos con Machine Learning usando el archivo generado.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# 1. Cargar el dataset
df = pd.read_excel('../Agrupacion_Insumos_Completo.xlsx')
df.head()
